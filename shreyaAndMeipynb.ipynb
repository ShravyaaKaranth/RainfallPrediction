# %%
import numpy as np
import pandas as pd
import matplotlib as mtlib

# %% [markdown]
# # New Section

# %%
import io

# %%
read = pd.read_csv('/content/main_data.csv')
read
# Out:
#                   Date  DOY       TMAX       TMIN    RAIN   HMAX   HMIN  \
# 0     01-01-2005 00:00    1  21.161111  14.272222   0.000  97.50  65.97
# 1     01-02-2005 00:00    2  21.261111   4.794444   0.000  99.30  77.37
# 2     01-03-2005 00:00    3   5.855556   3.477778   2.540  99.80  98.20
# 3     01-04-2005 00:00    4   4.644444   0.883333   7.620  99.60  98.50
# 4     01-05-2005 00:00    5   0.827778  -9.172222  24.130  99.40  86.80
# ...                ...  ...        ...        ...     ...    ...    ...
# 4547      6/14/17 0:00  165  32.761111  23.522222   0.000  84.24  54.32
# 4548      6/15/17 0:00  166  34.588889  22.911111   0.000  86.87  50.44
# 4549      6/16/17 0:00  167  35.527778  20.972222   0.000  90.35  38.94
# 4550      6/17/17 0:00  168  33.322222  25.088889   0.000  75.12  57.47
# 4551      6/18/17 0:00  169  26.477778  21.250000   0.254  96.40  58.87
#
#        ATOT     W2AVG   ETgrass
# 0      4.09  5.194592  1.976940
# 1      4.11  3.428788  1.302427
# ...

# %%
d = read.drop(['ATOT', 'W2AVG', 'ETgrass'],axis=1) 
d.head()
# Out:
#                Date  DOY       TMAX       TMIN   RAIN  HMAX   HMIN
# 0  01-01-2005 00:00    1  21.161111  14.272222   0.00  97.5  65.97
# 1  01-02-2005 00:00    2  21.261111   4.794444   0.00  99.3  77.37
# 2  01-03-2005 00:00    3   5.855556   3.477778   2.54  99.8  98.20
# 3  01-04-2005 00:00    4   4.644444   0.883333   7.62  99.6  98.50
# 4  01-05-2005 00:00    5   0.827778  -9.172222  24.13  99.4  86.80

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4552 entries, 0 to 4551
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    4552 non-null   object
#  1   DOY     4552 non-null   int64
#  2   TMAX    4536 non-null   float64
#  3   TMIN    4536 non-null   float64
#  4   RAIN    4521 non-null   float64
#  5   HMAX    4527 non-null   float64
#  6   HMIN    4527 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 249.1+ KB

# %%
d['TMAX'] = d['TMAX'].interpolate()
d['TMIN'] = d['TMIN'].interpolate()
d['RAIN'] = d['RAIN'].interpolate()
d['HMAX'] = d['HMAX'].interpolate()
d['HMIN'] = d['HMIN'].interpolate()
d
# Out:
#                   Date  DOY       TMAX       TMIN    RAIN   HMAX   HMIN
# 0     01-01-2005 00:00    1  21.161111  14.272222   0.000  97.50  65.97
# 1     01-02-2005 00:00    2  21.261111   4.794444   0.000  99.30  77.37
# 2     01-03-2005 00:00    3   5.855556   3.477778   2.540  99.80  98.20
# 3     01-04-2005 00:00    4   4.644444   0.883333   7.620  99.60  98.50
# 4     01-05-2005 00:00    5   0.827778  -9.172222  24.130  99.40  86.80
# ...                ...  ...        ...        ...     ...    ...    ...
# 4547      6/14/17 0:00  165  32.761111  23.522222   0.000  84.24  54.32
# 4548      6/15/17 0:00  166  34.588889  22.911111   0.000  86.87  50.44
# 4549      6/16/17 0:00  167  35.527778  20.972222   0.000  90.35  38.94
# 4550      6/17/17 0:00  168  33.322222  25.088889   0.000  75.12  57.47
# 4551      6/18/17 0:00  169  26.477778  21.250000   0.254  96.40  58.87
#
# [4552 rows x 7 columns]

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4552 entries, 0 to 4551
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    4552 non-null   object
#  1   DOY     4552 non-null   int64
#  2   TMAX    4552 non-null   float64
#  3   TMIN    4552 non-null   float64
#  4   RAIN    4552 non-null   float64
#  5   HMAX    4552 non-null   float64
#  6   HMIN    4552 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 249.1+ KB

# %%
import seaborn as sns

# %%
sns.heatmap(d.corr(), cmap='viridis')

# %%
sns.pairplot(d)

# %%
# from sklearn.preprocessing import MinMaxScaler

# %%
# data=[[0,1],[-1,18]]

# %%
# scaler=MinMaxScaler()

# %%
# print(scaler.fit(data))

# %%
# print(scaler.data_max_)

# %%
# print(scaler.transform(data))

# %%
# print(scaler.transform([[0, 1]]))

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4552 entries, 0 to 4551
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    4552 non-null   object
#  1   DOY     4552 non-null   int64
#  2   TMAX    4552 non-null   float64
#  3   TMIN    4552 non-null   float64
#  4   RAIN    4552 non-null   float64
#  5   HMAX    4552 non-null   float64
#  6   HMIN    4552 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 249.1+ KB

# %%
tm_list =read["TMAX"].tolist()

# %%
norm_tm= []
for i in read['TMAX'].values:
  z = (i - min(tm_list))/ (max(tm_list) - min(tm_list))
  norm_tm.append(z)

# %%
for i in range(10):
  print(norm_tm[i])
print(len(norm_tm))
# Out:
# 0.5748410908148968
# 0.5766864875751965
# 0.2923928644755128
# 0.27004305925103533
# 0.1996104162452335
# 0.15757637892319545
# 0.3409883124905864
# 0.3891736723408054
# 0.5418289931934758
# 0.5366003691008067
# 4552

# %%
tmin_list =read["TMIN"].tolist()

# %%
norm_tmin= []
for i in read['TMIN'].values:
  z = (i - min(tmin_list))/ (max(tmin_list) - min(tmin_list))
  norm_tmin.append(z)

# %%
for i in range(10):
  print(norm_tmin[i])

print(len(norm_tmin))
# Out:
# 0.718196994943693
# 0.5283249860882588
# 0.5019476906108884
# 0.4499721758564293
# 0.2485253200101152
# 0.210127991104499
# 0.32999443518330596
# 0.3155258764797646
# 0.5355592654600628
# 0.649860879222046
# 4552

# %%
train_list =read["RAIN"].tolist()

# %%
norm_train= []
for i in read['RAIN'].values:
  z = (i - min(train_list))/ (max(train_list) - min(train_list))
  norm_train.append(z)

# %%
for i in range(10):
  print(norm_train[i])
# Out:
# 0.023494860499265788
# 0.023494860499265788
# 0.03817914831130691
# 0.06754772393538915
# 0.1629955947136564
# 0.030837004405286344
# 0.032305433186490456
# 0.023494860499265788
# 0.023494860499265788
# 0.023494860499265788

# %%
thmax_list =read["HMAX"].tolist()

# %%
norm_thmax= []
for i in read['HMAX'].values:
  z = (i - min(thmax_list))/ (max(thmax_list) - min(thmax_list))
  norm_thmax.append(z)

# %%
for i in range(10):
  print(norm_thmax[i])
# Out:
# 0.9621785173978821
# 0.9894099848714071
# 0.9969742813918308
# 0.9939485627836611
# 0.9909228441754918
# 0.8835098335854766
# 0.903177004538578
# 0.957639939485628
# 0.9062027231467474
# 0.9909228441754918

# %%
thmin_list =read["HMIN"].tolist()

# %%
norm_thmin= []
for i in read['HMIN'].values:
  z = (i - min(thmin_list))/ (max(thmin_list) - min(thmin_list))
  norm_thmin.append(z)

# %%
for i in range(10):
  print(norm_tmin[i])
# Out:
# 0.718196994943693
# 0.5283249860882588
# 0.5019476906108884
# 0.4499721758564293
# 0.2485253200101152
# 0.210127991104499
# 0.32999443518330596
# 0.3155258764797646
# 0.5355592654600628
# 0.649860879222046

# %%
blah1=pd.DataFrame()

# %%
print(len(norm_tmin))
# Out:
# 4552

# %%
print(len(norm_tm))
# Out:
# 4552

# %%
print(len(norm_thmin))
# Out:
# 4552

# %%
print(len(norm_thmax))
# Out:
# 4552

# %%
print(len(norm_train))
# Out:
# 4552

# %%
blah1['TMAX'] = norm_tm
blah1['TMIN'] = norm_tmin
blah1['RAIN'] = norm_train
blah1['HMAX'] = norm_thmax
blah1['HMIN'] = norm_thmin
blah1.head()
# Out:
#        TMAX      TMIN      RAIN      HMAX      HMIN
# 0  0.574841  0.718197  0.023495  0.962179  0.643637
# 1  0.576686  0.528325  0.023495  0.989410  0.764438
# 2  0.292393  0.501948  0.038179  0.996974  0.985165
# 3  0.270043  0.449972  0.067548  0.993949  0.988344
# 4  0.199610  0.248525  0.162996  0.990923  0.864364

# %%
from sklearn.model_selection import train_test_split

# %%
y=blah1['RAIN']

# %%
x=blah1.loc[:,('TMAX','TMIN','HMAX','HMIN')]

# %%
blah1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4552 entries, 0 to 4551
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   TMAX    4536 non-null   float64
#  1   TMIN    4536 non-null   float64
#  2   RAIN    4521 non-null   float64
#  3   HMAX    4527 non-null   float64
#  4   HMIN    4527 non-null   float64
# dtypes: float64(5)
# memory usage: 177.9 KB

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.8,random_state=0)

# %%
print(x_train.head())
# Out:
#           TMAX      TMIN      HMAX      HMIN
# 4498  0.468936  0.524318  0.927988  0.424711
# 1882  0.328788  0.415915  0.977307  0.600509
# 771   0.314845  0.432610  0.930408  0.743880
# 4327  0.486775  0.694713  0.975492  0.655505
# 51    0.492516  0.531886  0.954614  0.368125

# %%
d['TMAX'] = d['TMAX'].interpolate()
d['TMIN'] = d['TMIN'].interpolate()
d['RAIN'] = d['RAIN'].interpolate()
d['HMAX'] = d['HMAX'].interpolate()
d['HMIN'] = d['HMIN'].interpolate()
d
# Out:
#                   Date  DOY       TMAX       TMIN    RAIN   HMAX   HMIN
# 0     01-01-2005 00:00    1  21.161111  14.272222   0.000  97.50  65.97
# 1     01-02-2005 00:00    2  21.261111   4.794444   0.000  99.30  77.37
# 2     01-03-2005 00:00    3   5.855556   3.477778   2.540  99.80  98.20
# 3     01-04-2005 00:00    4   4.644444   0.883333   7.620  99.60  98.50
# 4     01-05-2005 00:00    5   0.827778  -9.172222  24.130  99.40  86.80
# ...                ...  ...        ...        ...     ...    ...    ...
# 4547      6/14/17 0:00  165  32.761111  23.522222   0.000  84.24  54.32
# 4548      6/15/17 0:00  166  34.588889  22.911111   0.000  86.87  50.44
# 4549      6/16/17 0:00  167  35.527778  20.972222   0.000  90.35  38.94
# 4550      6/17/17 0:00  168  33.322222  25.088889   0.000  75.12  57.47
# 4551      6/18/17 0:00  169  26.477778  21.250000   0.254  96.40  58.87
#
# [4552 rows x 7 columns]

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4552 entries, 0 to 4551
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    4552 non-null   object
#  1   DOY     4552 non-null   int64
#  2   TMAX    4552 non-null   float64
#  3   TMIN    4552 non-null   float64
#  4   RAIN    4552 non-null   float64
#  5   HMAX    4552 non-null   float64
#  6   HMIN    4552 non-null   float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 249.1+ KB

# %%
from sklearn.neural_network import MLPRegressor
